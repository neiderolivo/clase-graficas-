# %%
from numpy import array
from numpy import array
from numpy import arange
from pylab import plot, show
from pylab import savefig
from numpy import linspace, sin, cos 
from pylab import ylim, xlim, grid,xlabel,ylabel
from numpy import loadtxt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# en la grafica  de año vs average se puede obsservar de manera general un comportamiento un poco lineal que muestra que a medida que van aumentando los años o que pasa el tiempo tambien va aumentando el el valor promedio  de producion de co2; y se espera que si no se toman medias de solucion  o contencion,lo que se espera es que siga asi debido a la tendencia a crecer que posee el fenomeno.
# ahora si analizamos mas detenidamente la grafica, se puede ver que aparte de ese comportamiento de forma lineal tambien presenta pequeñass osciaciones que tambien van variando, debido a que en los primeros años la amplitud de la oscilacion es mas pequeña, es decir (),mientras que para los años finales la amplitud de las oscilaciones aumenta queriendo dar a entender que (),mostarandose asi la tendencia de crecimiento de foma anual como de forma general, lo que lleva a la conclusion de que se debe prestar mucha atencion a este fenomeno y tratar de corregirlo porque si no seguira en aumento, hasta que ya no pueda ser controlado.

# %%
from numpy import loadtxt
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
dataco2= loadtxt("co2_mm_gl.txt",float)
plot(dataco2[:,2], dataco2[:,3])
xlabel("año")
ylabel("promedio")

plt.show()

# %%
dataco2= loadtxt("co2_mm_gl.txt",float)
plot(dataco2[:,2], dataco2[:,3])
xlim(1980.,2000)
ylim(336,370)
xlabel("año")
ylabel("promedio")
show()

# %%
dataco2= loadtxt("co2_mm_gl.txt",float)
plot(dataco2[:,2], dataco2[:,3])
xlim(2000.,2020)
ylim(365,415)
xlabel("año")
ylabel("promedio")
show()
